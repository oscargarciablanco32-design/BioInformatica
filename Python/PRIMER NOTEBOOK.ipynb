# %% [markdown]
# # PRIMER NOTEBOOK

# %% [markdown]
# #### Este es mi primer notebook y voy a hacer lo siguiente.

# %% [markdown]
# Una lista **enumerada**:
# 1. Primero
# 2. Segundo
# 3. Tercero
#
# Una lista **por puntos**:
# - Primero
# - Segundo
# - Tercero
#
# Mi primer código:

# %%
mi_primera_frase = "Hello World"

# %%
# Como cuando lo ejecuto no sale nada, tengo que usar la funcion print()
print(mi_primera_frase)
# Out:
# Hello World

# %%
# A ver si así lo entiendes mejor:
numeros = [10,20,30,40,50]

# %%
media = sum(numeros) /len(numeros)
print(media)
# Out:
# 30.0

# %% [markdown]
# #### Finalizamos con una bonita imagen

# %% [markdown]
# ![Llama](https://upload.wikimedia.org/wikipedia/commons/thumb/d/db/Alpaca_%2831562329701%29.jpg/500px-Alpaca_%2831562329701%29.jpg)
